# %%
import testing
from importlib import reload

reload(testing)
from testing import *

# %%
# %%capture
test = Test(r"T8_Open_Lab_2\15_100")

# %%
# %matplotlib qt
# q to quit
test.interactive("Rohan", 0)
# Out:
# T8_Open_Lab_2\15_100\test_1-04062026171731-0.tiff

# %%
# ! jupyter nbconvert --to script interactive.ipynb
# Out:
# [NbConvertApp] Converting notebook interactive.ipynb to script
# [NbConvertApp] Writing 423 bytes to interactive.py
